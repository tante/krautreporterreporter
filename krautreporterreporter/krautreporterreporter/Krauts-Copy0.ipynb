# %%
import json
raw = json.load(open("/home/tante/krauter.json","r"))
data = [{"name":e['name'],'amount':e['amount'].} for e in ]

# %%
sorted(data, key=lambda tup: tup['amount'])
# Out:
# [{'name': 'mayst', 'amount': '1.000'},
#  {'name': 'DMAG', 'amount': '1.500'},
#  {'name': 'Settembrini', 'amount': '10.000'},
#  {'name': 'QMensch', 'amount': '100'},
#  {'name': 'Mark Weishaupt', 'amount': '100'},
#  {'name': 'Lothar C.Poll', 'amount': '100'},
#  {'name': 'n-ost', 'amount': '100'},
#  {'name': 'oheckmann', 'amount': '100'},
#  {'name': 'krautshopper', 'amount': '100'},
#  {'name': 'rpr', 'amount': '100'},
#  {'name': 'guteidee', 'amount': '100'},
#  {'name': 'Orion', 'amount': '100'},
#  {'name': 'Andreas Laible', 'amount': '100'},
#  {'name': 'jetztgleich', 'amount': '100'},
#  {'name': 'Ioreth', 'amount': '100'},
#  {'name': 'jumaba', 'amount': '100'},
#  {'name': 'matthes04', 'amount': '100'},
#  {'name': 'Dave-Kay', 'amount': '100'},
#  {'name': 'gesine.kerber', 'amount': '100'},
#  {'name': 'Rebecca Harms', 'amount': '100'},
#  {'name': 'bernd.bass.52', 'amount': '100'},
#  {'name': 'frank.roth.581', 'amount': '100'},
#  {'name': 'Hoerkens', 'amount': '100'},
# ...
